# %%
import os

# %%
# Whether path really exist or not
os.path.exists('/Users/yasibodaghi/Desktop/Work/project/test.html')
# Out:
# True

# %%
os.path.isfile('/Users/yasibodaghi/Desktop/Work/project/test.html')
# Out:
# True

# %%
os.path.isdir('/Users/yasibodaghi/Desktop/Work/project/test.html')
# Out:
# False

# %%
# Split the file name from the path
os.path.split('/Users/yasibodaghi/Desktop/Work/project/test.html')
# Out:
# ('/Users/yasibodaghi/Desktop/Work/project', 'test.html')

# %%
# Join the path name and file name
os.path.join('/Users/yasibodaghi/Desktop/Work/project','test.html')
# Out:
# '/Users/yasibodaghi/Desktop/Work/project/test.html'

# %%
# Give the file name
os.path.basename('/Users/yasibodaghi/Desktop/Work/project/test.html')
# Out:
# 'test.html'

# %%
# Get the last time file has been accessed.
import time
time.ctime(os.path.getatime('/Users/yasibodaghi/Desktop/Work/project/test.html'))
# Out:
# 'Sat Nov 22 20:21:28 2025'

# %%
# Get the last time file has been modified.
import time
time.ctime(os.path.getmtime('/Users/yasibodaghi/Desktop/Work/project/test.html'))
# Out:
# 'Tue Sep 16 21:16:26 2025'
